# %% [markdown]
# ## Introduction

# %% [markdown]
# ### This project is to find a suitable location for a coffee shop equipped with EV charging station.

# %% [markdown]
# #### As we know the world is moving towards a 'electrified' life. I see a future where electric charge stations are a part of our daily life.

# %% [markdown]
# #### As the world is trying to move on from fossil fuels to much more eco-friendly sources of energy.
# #### One of the big step towards this is making cars that purely runs on electricity.
# #### As we know, much like charging a phone it takes time to charge cars.
# #### So there is going to be a market for charging stations along highways and also cafes and restaurants nearby the      stations.

# %% [markdown]
# #### My project focuses on suitable location for a coffee shop equipped with EV charging stations, which also give the customers other options to spend their time which would be typically 2 to 3 hours. This time is the average time for cars to be recharged

# %% [markdown]
# #### This project is targeted towards business persons who want to venture into futuristic lifestyle.

# %% [markdown]
# #### We are going to find a coffee shop on the route from New York to Toronto

# %%
import folium

# %%
new_york_map=folium.Map(location=[40.71,-74.00],zoom_start=8)
new_york_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
client_id='TO0QRR0ZYDUJ4D0XIPMR3BSP0FGYZFSPBMSPPJH0F4CW3LEE'
client_secret='OLMGUBDLEG4YUHWOCSKXTONDBV2ROBG4PI50VDHZB1BQCGJM'
print('client_id is {} \nclient_secret is {}'.format(client_id,client_secret))
# Out:
# client_id is TO0QRR0ZYDUJ4D0XIPMR3BSP0FGYZFSPBMSPPJH0F4CW3LEE
# client_secret is OLMGUBDLEG4YUHWOCSKXTONDBV2ROBG4PI50VDHZB1BQCGJM

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !pip install geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# ...
#      |████████████████████████████████| 112kB 5.9MB/s eta 0:00:01
# ...
# Folium installed
# Libraries imported.

# %%
latitude=40.71
longitude=-74.00
radius=200
limit=20
search_query='C'
version='20200812'

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(client_id, client_secret, latitude, longitude, version, radius, limit)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=TO0QRR0ZYDUJ4D0XIPMR3BSP0FGYZFSPBMSPPJH0F4CW3LEE&client_secret=OLMGUBDLEG4YUHWOCSKXTONDBV2ROBG4PI50VDHZB1BQCGJM&ll=40.71,-74.0&v=20200812&radius=200&limit=20'

# %%
results=requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5f4696218758c95cfe2c7487'},
#  'response': {'venues': [{'id': '4a43bcb7f964a520bba61fe3',
#     'name': 'Brooklyn Bridge',
#     'location': {'address': 'Brooklyn Bridge',
#      'lat': 40.70596749893083,
#      'lng': -73.99670720100403,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.70596749893083,
#        'lng': -73.99670720100403}],
#      'distance': 527,
#      'postalCode': '10038',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Brooklyn Bridge',
#       'New York, NY 10038',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1df941735',
#       'name': 'Bridge',
#       'pluralName': 'Bridges',
#       'shortName': 'Bridge',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/bridge_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598461537',
# ...

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, version, search_query, radius, limit)
url
